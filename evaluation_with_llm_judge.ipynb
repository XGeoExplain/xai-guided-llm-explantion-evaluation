# %%
import os
import json
import time
import pandas as pd

# %% [markdown]
# # Load LLM explanations (CSV)

# %%
exp1 = pd.read_csv(f"exp1_results_scaled.csv")
exp2 = pd.read_csv(f"exp2_results_scaled.csv")
exp3 = pd.read_csv(f"exp3_results_scaled.csv")
exp4 = pd.read_csv(f"exp4_results_scaled.csv")

# Check shapes
print("Exp1:", exp1.shape)
print("Exp2:", exp2.shape)
print("Exp3:", exp3.shape)
print("Exp4:", exp4.shape)
# Out:
# Exp1: (120, 5)
# Exp2: (120, 6)
# Exp3: (120, 6)
# Exp4: (120, 6)

# %%
exp1.head()
# Out:
#          true_class   predicted_class  confidence  \
# 0  annual crop land  annual crop land       100.0
# 1  annual crop land  annual crop land       100.0
# 2  annual crop land  annual crop land       100.0
# 3  annual crop land  annual crop land        99.5
# 4  annual crop land  annual crop land        99.9
#
#                                   direct_description  image_idx
# 0  The model likely predicted "annual crop land" ...          0
# 1  The model likely predicted "annual crop land" ...          1
# 2  The image shows a pattern of uniform, rectangu...          2
# 3  The model likely predicted "annual crop land" ...          3
# 4  The model likely predicted "annual crop land" ...          4

# %%
exp2.head()
# Out:
#          true_class   predicted_class  confidence  \
# 0  annual crop land  annual crop land       100.0
# 1  annual crop land  annual crop land       100.0
# 2  annual crop land  annual crop land       100.0
# 3  annual crop land  annual crop land        99.5
# 4  annual crop land  annual crop land        99.9
#
#                             gradcam_region  \
# 0   bottom-left region, strongly activated
# 1  bottom-right region, strongly activated
# 2  bottom-right region, strongly activated
# 3   bottom-left region, strongly activated
# 4  bottom-right region, strongly activated
#
#                                      xai_explanation  image_idx
# 0  The model likely predicted "annual crop land" ...          0
# 1  The model likely predicted "annual crop land" ...          1
# 2  The model likely predicted "annual crop land" ...          2
# 3  The model likely predicted "annual crop land" ...          3
# 4  The model likely predicted "annual crop land" ...          4

# %%
exp3.head()
# Out:
#          true_class   predicted_class  confidence  \
# 0  annual crop land  annual crop land       100.0
# 1  annual crop land  annual crop land       100.0
# 2  annual crop land  annual crop land       100.0
# 3  annual crop land  annual crop land        99.5
# 4  annual crop land  annual crop land        99.9
#
#                                     lime_description  \
# 0  5 important segments in the upper-center, lowe...
# 1  5 important segments in the middle-center, mid...
# 2  5 important segments in the middle-left, lower...
# 3  5 important segments in the upper-right, lower...
# 4  5 important segments in the lower-center, midd...
#
#                                     lime_explanation  image_idx
# 0  The model likely predicted "annual crop land" ...          0
# 1  The model likely predicted "annual crop land" ...          1
# 2  The model likely identified the area as "annua...          2
# 3  The model likely predicted "annual crop land" ...          3
# 4  The model likely predicted "annual crop land" ...          4

# %%
exp4.head()
# Out:
#          true_class   predicted_class  confidence  \
# 0  annual crop land  annual crop land       100.0
# 1  annual crop land  annual crop land       100.0
# 2  annual crop land  annual crop land       100.0
# 3  annual crop land  annual crop land        99.5
# 4  annual crop land  annual crop land        99.9
#
#                                     shap_description  \
# 0  middle-right and upper-left regions, moderatel...
# 1  middle-center and middle-right regions, modera...
# 2  upper-left and middle-left regions, moderately...
# 3  middle-left and upper-left regions, moderately...
# 4  lower-left and upper-center regions, moderatel...
#
#                                     shap_explanation  image_idx
# 0  The model predicted "annual crop land" likely ...          0
# 1  The model likely predicted "annual crop land" ...          1
# 2  The CNN model likely identified patterns in th...          2
# 3  The model likely predicted "annual crop land" ...          3
# 4  The model likely predicted "annual crop land" ...          4

# %% [markdown]
# # Align Rows

# %% [markdown]
# must ensure:
# Same image = same row across all experiments
# Otherwise comparisons become wrong

# %%
# Sort all dataframes the same way
sort_cols = ["true_class", "image_idx"]

exp1 = exp1.sort_values(sort_cols).reset_index(drop=True)
exp2 = exp2.sort_values(sort_cols).reset_index(drop=True)
exp3 = exp3.sort_values(sort_cols).reset_index(drop=True)
exp4 = exp4.sort_values(sort_cols).reset_index(drop=True)

# Check alignment
for i in range(5):
    print(
        exp1.loc[i, "true_class"], 
        exp1.loc[i, "image_idx"],
        "|",
        exp2.loc[i, "image_idx"],
        exp3.loc[i, "image_idx"],
        exp4.loc[i, "image_idx"]
    )
# Out:
# annual crop land 0 | 0 0 0
# annual crop land 1 | 1 1 1
# annual crop land 2 | 2 2 2
# annual crop land 3 | 3 3 3
# annual crop land 4 | 4 4 4

# %% [markdown]
# # Create LLM Judge for Text Comparison

# %%
def build_judge_prompt(predicted_class, baseline_explanation, xai_explanation, xai_method):
    """
    Pairwise comparison: Baseline vs XAI-informed explanation
    
    Args:
        predicted_class: The class predicted by the model
        baseline_explanation: Explanation from Exp1 (image + prediction only)
        xai_explanation: Explanation from Exp2/3/4 (image + prediction + XAI guidance)
        xai_method: "GradCAM", "LIME", or "SHAP"
    """
    return f"""You are evaluating two explanations for why a CNN model predicted a specific class for a satellite image.

The model predicted: "{predicted_class}"

Explanation A:
\"\"\"{baseline_explanation}\"\"\"

Explanation B:
\"\"\"{xai_explanation}\"\"\"

Evaluate both explanations on these criteria:

1. Specificity (0-5 points):
   - Does the explanation mention concrete visual features?
   - Examples: shapes (rectangular, circular), textures (rough, smooth), 
     patterns (grid-like, uniform), colors (green, brown), 
     spatial layout (clustered, linear, scattered)
   - Avoid vague terms like "typical" or "characteristic"
   
   Score 5: Multiple specific visual features clearly described
   Score 3: Some specific features mentioned
   Score 1: Only vague, general descriptions
   Score 0: No visual features mentioned

2. Usefulness (0-5 points):
   - Does the explanation help a human understand the model's reasoning?
   - Does it connect visual features to the predicted class?
   - Would a non-technical user (city planner, policy maker) find this explanation helpful?
   
   Score 5: Very clear connection between features and prediction
   Score 3: Some helpful information but not fully clear
   Score 1: Minimal help in understanding the reasoning
   Score 0: Confusing or unhelpful

Total Score = Specificity + Usefulness (0 to 10)

IMPORTANT: Return ONLY valid JSON. Do NOT use markdown formatting or code blocks.

{{
  "score_A": <number 0-10>,
  "score_B": <number 0-10>,
  "specificity_A": <number 0-5>,
  "specificity_B": <number 0-5>,
  "usefulness_A": <number 0-5>,
  "usefulness_B": <number 0-5>,
  "winner": "A" or "B" or "Tie",
  "reason": "<brief 1-sentence explanation of why winner was chosen>"
}}
"""

# %%
from openai import OpenAI
import json
import re
import time

API_KEY = "api-key-here"

client = OpenAI(api_key=API_KEY)

# %%
def judge_with_openai(prompt):

    while True:
        try:
            response = client.chat.completions.create(
                model="gpt-4.1-mini",
                messages=[
                    {
                        "role": "user",
                        "content": prompt
                    }
                ],
                temperature=0,   # 🔥 important for consistency
                max_tokens=300
            )

            text = response.choices[0].message.content.strip()

            # Extract JSON safely
            match = re.search(r"\{.*\}", text, re.DOTALL)

            if match:
                json_text = match.group(0)
                result = json.loads(json_text)
                return result
            else:
                print("No JSON found:", text)
                return {
                    "score_A": None,
                    "score_B": None,
                    "winner": "Error",
                    "reason": "No JSON found"
                }

        except Exception as e:
            error_str = str(e)

            # 🔥 Handle rate limits
            if "429" in error_str:
                print("⏳ Rate limit hit. Waiting 5 seconds...")
                time.sleep(5)
                continue

            print("Error:", e)
            return {
                "score_A": None,
                "score_B": None,
                "winner": "Error",
                "reason": "Parsing failed"
            }

# %% [markdown]
# # Exp1 vs Exp2 (base vs Grad-CAM)

# %%
# Pick first sample
i = 100

predicted_class = exp1.loc[i, "predicted_class"]

# Exp1 = baseline
exp1_text = exp1.loc[i, "direct_description"]
print("exp1_text:")
print(exp1_text)

# Exp2 = GradCAM (you can later switch to exp3 or exp4)
exp2_text = exp2.loc[i, "xai_explanation"]
print("\nexp2_text:")
print(exp2_text)

# Build prompt (no bias mention)
prompt = build_judge_prompt(
    predicted_class,
    exp1_text,
    exp2_text,
    "GradCAM"   # not shown to model, just your variable
)

# Call Gemini
result = judge_with_openai(prompt)

print("\nResult:")
print(result)
# Out:
# exp1_text:
# The model likely predicted the class "river" due to the elongated, winding shape visible in the image, typical of river formations. The smooth, continuous texture and the dark color of this feature contrast with the surrounding areas, which aligns with how water bodies often appear in satellite images. Additionally, the linear pattern running parallel to this feature may resemble banks or shorelines, reinforcing the identification of a river.
#
# exp2_text:
# The model likely predicted the class "river" because in the bottom-right region, there is a distinct elongated, winding shape consistent with a river. This area shows a different texture compared to the surrounding land, suggesting the presence of water. The continuous, curved pattern follows the characteristic flow of a river, helping the model to identify it accurately.
# No JSON found:
#
# Result:
# {'score_A': None, 'score_B': None, 'winner': 'Error', 'reason': 'No JSON found'}

# %%
results_base_vs_gradcam = []

for i in range(len(exp1)):

  #  time.sleep(15)
    
    predicted_class = exp1.loc[i, "predicted_class"]

    exp1_text = exp1.loc[i, "direct_description"]
    exp2_text = exp2.loc[i, "xai_explanation"]

    prompt = build_judge_prompt(
        predicted_class,
        exp1_text,
        exp2_text,
        "GradCAM"
    )

    result = judge_with_openai(prompt)

    winner_raw = result.get("winner")

    if winner_raw == "A":
        winner_label = "base"
    elif winner_raw == "B":
        winner_label = "GradCAM"
    elif winner_raw == "Tie":
        winner_label = "Tie"
    else:
        winner_label = "Error"

    results_base_vs_gradcam.append({
        "index": i,
        "true_class": exp1.loc[i, "true_class"],
        "predicted_class": predicted_class,
        "score_base": result.get("score_A"),
        "score_gradcam": result.get("score_B"),
        "winner": winner_label,
        "specificity_base": result.get("specificity_A"),
        "specificity_gradcam": result.get("specificity_B"),
        "usefulness_base": result.get("usefulness_A"),
        "usefulness_gradcam": result.get("usefulness_B"),
        "reason": result.get("reason")
    })

    # IMPORTANT: avoid rate limit
    #time.sleep(12)

    # Progress update
    if i % 10 == 0:
        print(f"Processed {i}/{len(exp1)}")
# Out:
# Processed 0/120
# Processed 10/120
# Processed 20/120
# Processed 30/120
# Processed 40/120
# Processed 50/120
# Processed 60/120
# Processed 70/120
# Processed 80/120
# Processed 90/120
# Processed 100/120
# Processed 110/120

# %%
df_exp12 = pd.DataFrame(results_base_vs_gradcam)

df_exp12.head()
# Out:
#    index        true_class   predicted_class  score_base  score_gradcam  \
# 0      0  annual crop land  annual crop land           9              8
# 1      1  annual crop land  annual crop land           8              7
# 2      2  annual crop land  annual crop land           9              7
# 3      3  annual crop land  annual crop land           8              9
# 4      4  annual crop land  annual crop land           9              8
#
#     winner  specificity_base  specificity_gradcam  usefulness_base  \
# 0     base                 5                    4                4
# 1     base                 4                    3                4
# 2     base                 5                    3                4
# 3  GradCAM                 4                    5                4
# 4     base                 5                    4                4
#
#    usefulness_gradcam                                             reason
# 0                   4  Explanation A provides a slightly more detaile...
# 1                   4  Explanation A provides more specific visual fe...
# 2                   4  Explanation A provides multiple concrete visua...
# 3                   4  Explanation B provides more specific visual de...
# 4                   4  Explanation A provides a broader set of concre...

# %%
win_counts = df_exp12["winner"].value_counts()

print(win_counts)
# Out:
# winner
# base       56
# GradCAM    42
# Tie        22
# Name: count, dtype: int64

# %%
total = len(df_exp12)

gradcam_wins = (df_exp12["winner"] == "GradCAM").sum()
base_wins = (df_exp12["winner"] == "base").sum()
ties = (df_exp12["winner"] == "Tie").sum()

print(f"GradCAM win rate: {gradcam_wins/total*100:.2f}%")
print(f"Baseline win rate: {base_wins/total*100:.2f}%")
print(f"Tie rate: {ties/total*100:.2f}%")
# Out:
# GradCAM win rate: 35.00%
# Baseline win rate: 46.67%
# Tie rate: 18.33%

# %%
avg_base = df_exp12["score_base"].mean()
avg_gradcam = df_exp12["score_gradcam"].mean()

print(f"Avg Base Score: {avg_base:.2f}")
print(f"Avg GradCAM Score: {avg_gradcam:.2f}")
# Out:
# Avg Base Score: 8.15
# Avg GradCAM Score: 8.21

# %%
improvement = ((avg_gradcam - avg_base) / avg_base) * 100

print(f"Improvement: {improvement:.2f}%")
# Out:
# Improvement: 0.72%

# %% [markdown]
# # Exp1 vs Exp3 (base vs LIME)

# %%
results_base_vs_lime = []

for i in range(len(exp1)):

    predicted_class = exp1.loc[i, "predicted_class"]

    exp1_text = exp1.loc[i, "direct_description"]
    exp3_text = exp3.loc[i, "lime_explanation"]

    prompt = build_judge_prompt(
        predicted_class,
        exp1_text,
        exp3_text,
        "LIME"
    )

    result = judge_with_openai(prompt)

    # Map winner labels
    winner_raw = result.get("winner")

    if winner_raw == "A":
        winner_label = "base"
    elif winner_raw == "B":
        winner_label = "LIME"
    elif winner_raw == "Tie":
        winner_label = "Tie"
    else:
        winner_label = "Error"

    results_base_vs_lime.append({
        "index": i,
        "true_class": exp1.loc[i, "true_class"],
        "predicted_class": predicted_class,
        "score_base": result.get("score_A"),
        "score_lime": result.get("score_B"),
        "winner": winner_label,
        "specificity_base": result.get("specificity_A"),
        "specificity_lime": result.get("specificity_B"),
        "usefulness_base": result.get("usefulness_A"),
        "usefulness_lime": result.get("usefulness_B"),
        "reason": result.get("reason")
    })

    if i % 10 == 0:
        print(f"Processed {i}/{len(exp1)}")
# Out:
# Processed 0/120
# Processed 10/120
# Processed 20/120
# Processed 30/120
# Processed 40/120
# Processed 50/120
# Processed 60/120
# Processed 70/120
# Processed 80/120
# Processed 90/120
# Processed 100/120
# Processed 110/120

# %%
df_exp13 = pd.DataFrame(results_base_vs_lime)

df_exp13.head()
# Out:
#    index        true_class   predicted_class  score_base  score_lime winner  \
# 0      0  annual crop land  annual crop land           9           9    Tie
# 1      1  annual crop land  annual crop land           8           9   LIME
# 2      2  annual crop land  annual crop land           9           8   base
# 3      3  annual crop land  annual crop land           8           9   LIME
# 4      4  annual crop land  annual crop land           8           9   LIME
#
#    specificity_base  specificity_lime  usefulness_base  usefulness_lime  \
# 0                 5                 5                4                4
# 1                 4                 5                4                4
# 2                 5                 4                4                4
# 3                 4                 5                4                4
# 4                 4                 5                4                4
#
#                                               reason
# 0  Both explanations provide multiple specific vi...
# 1  Explanation B provides more precise spatial de...
# 2  Explanation A provides more multiple specific ...
# 3  Explanation B provides more specific visual de...
# 4  Explanation B provides a more detailed and spe...

# %%
win_counts = df_exp13["winner"].value_counts()
print(win_counts)
# Out:
# winner
# LIME    65
# base    47
# Tie      8
# Name: count, dtype: int64

# %%
total = len(df_exp13)

lime_wins = (df_exp13["winner"] == "LIME").sum()
base_wins = (df_exp13["winner"] == "base").sum()
ties = (df_exp13["winner"] == "Tie").sum()

print(f"LIME win rate: {lime_wins/total*100:.2f}%")
print(f"Baseline win rate: {base_wins/total*100:.2f}%")
print(f"Tie rate: {ties/total*100:.2f}%")
# Out:
# LIME win rate: 54.17%
# Baseline win rate: 39.17%
# Tie rate: 6.67%

# %%
avg_base = df_exp13["score_base"].mean()
avg_lime = df_exp13["score_lime"].mean()

print(f"Avg Base Score: {avg_base:.2f}")
print(f"Avg LIME Score: {avg_lime:.2f}")
# Out:
# Avg Base Score: 7.92
# Avg LIME Score: 8.37

# %%
improvement = ((avg_lime - avg_base) / avg_base) * 100

print(f"Improvement: {improvement:.2f}%")
# Out:
# Improvement: 5.68%

# %% [markdown]
# # Exp1 vs Exp4 (base vs SHAP)

# %%
results_base_vs_shap = []

for i in range(len(exp1)):

    predicted_class = exp1.loc[i, "predicted_class"]

    exp1_text = exp1.loc[i, "direct_description"]
    exp4_text = exp4.loc[i, "shap_explanation"]

    prompt = build_judge_prompt(
        predicted_class,
        exp1_text,
        exp4_text,
        "SHAP"
    )

    result = judge_with_openai(prompt)

    # Map winner labels
    winner_raw = result.get("winner")

    if winner_raw == "A":
        winner_label = "base"
    elif winner_raw == "B":
        winner_label = "SHAP"
    elif winner_raw == "Tie":
        winner_label = "Tie"
    else:
        winner_label = "Error"

    results_base_vs_shap.append({
        "index": i,
        "true_class": exp1.loc[i, "true_class"],
        "predicted_class": predicted_class,
        "score_base": result.get("score_A"),
        "score_shap": result.get("score_B"),
        "winner": winner_label,
        "specificity_base": result.get("specificity_A"),
        "specificity_shap": result.get("specificity_B"),
        "usefulness_base": result.get("usefulness_A"),
        "usefulness_shap": result.get("usefulness_B"),
        "reason": result.get("reason")
    })

    if i % 10 == 0:
        print(f"Processed {i}/{len(exp1)}")
# Out:
# Processed 0/120
# Processed 10/120
# Processed 20/120
# Processed 30/120
# Processed 40/120
# Processed 50/120
# Processed 60/120
# Processed 70/120
# Processed 80/120
# Processed 90/120
# Processed 100/120
# Processed 110/120

# %%
df_exp14 = pd.DataFrame(results_base_vs_shap)

df_exp14.head()
# Out:
#    index        true_class   predicted_class  score_base  score_shap winner  \
# 0      0  annual crop land  annual crop land           9           9    Tie
# 1      1  annual crop land  annual crop land           8           9   SHAP
# 2      2  annual crop land  annual crop land           9           7   base
# 3      3  annual crop land  annual crop land           9           8   base
# 4      4  annual crop land  annual crop land           9           9    Tie
#
#    specificity_base  specificity_shap  usefulness_base  usefulness_shap  \
# 0                 5                 5                4                4
# 1                 4                 5                4                4
# 2                 5                 3                4                4
# 3                 5                 4                4                4
# 4                 5                 5                4                4
#
#                                               reason
# 0  Both explanations provide multiple specific vi...
# 1  Explanation B provides more precise spatial de...
# 2  Explanation A provides more detailed and concr...
# 3  Explanation A provides more detailed and varie...
# 4  Both explanations provide multiple specific vi...

# %%
win_counts = df_exp14["winner"].value_counts()
print(win_counts)
# Out:
# winner
# base    62
# SHAP    43
# Tie     15
# Name: count, dtype: int64

# %%
total = len(df_exp14)

shap_wins = (df_exp14["winner"] == "SHAP").sum()
base_wins = (df_exp14["winner"] == "base").sum()
ties = (df_exp14["winner"] == "Tie").sum()

print(f"SHAP win rate: {shap_wins/total*100:.2f}%")
print(f"Baseline win rate: {base_wins/total*100:.2f}%")
print(f"Tie rate: {ties/total*100:.2f}%")
# Out:
# SHAP win rate: 35.83%
# Baseline win rate: 51.67%
# Tie rate: 12.50%

# %%
avg_base = df_exp14["score_base"].mean()
avg_shap = df_exp14["score_shap"].mean()

print(f"Avg Base Score: {avg_base:.2f}")
print(f"Avg SHAP Score: {avg_shap:.2f}")
# Out:
# Avg Base Score: 8.21
# Avg SHAP Score: 8.10

# %%
improvement = ((avg_shap - avg_base) / avg_base) * 100

print(f"Improvement: {improvement:.2f}%")
# Out:
# Improvement: -1.32%

# %% [markdown]
# # Save all results to CSV

# %%
df_exp12.to_csv(f"exp2_gradcam_evaluation.csv", index=False)

# %%
df_exp13.to_csv(f"exp3_lime_evaluation.csv", index=False)

# %%
df_exp14.to_csv(f"exp4_shap_evaluation.csv", index=False)

# %% [markdown]
# # Exp1 vs Exp5 (base vs combined XAI)

# %%
def build_combined_judge_prompt(predicted_class, baseline_explanation, combined_explanation):
    
    return f"""You are evaluating two explanations for why a CNN model predicted a specific class for a satellite image.

The model predicted: "{predicted_class}"

Explanation A :
\"\"\"{baseline_explanation}\"\"\"

Explanation B :
\"\"\"{combined_explanation}\"\"\"

Evaluate both explanations on these criteria:

1. Specificity (0-5 points):
   - Does the explanation mention concrete visual features?
   - Examples: shapes (rectangular, circular), textures (rough, smooth), 
     patterns (grid-like, uniform), colors (green, brown), 
     spatial layout (clustered, linear, scattered)
   - Avoid vague terms like "typical" or "characteristic"
   
   Score 5: Multiple specific visual features clearly described
   Score 3: Some specific features mentioned
   Score 1: Only vague, general descriptions
   Score 0: No visual features mentioned

2. Usefulness (0-5 points):
   - Does the explanation help a human understand the model's reasoning?
   - Does it connect visual features to the predicted class?
   - Would a non-technical user (city planner, policy maker) find this explanation helpful?
   
   Score 5: Very clear connection between features and prediction
   Score 3: Some helpful information but not fully clear
   Score 1: Minimal help in understanding the reasoning
   Score 0: Confusing or unhelpful

Total Score = Specificity + Usefulness (0 to 10)

Return ONLY valid JSON. Do NOT use markdown formatting or code blocks.

{{
  "score_A": <number 0-10>,
  "score_B": <number 0-10>,
  "specificity_A": <number 0-5>,
  "specificity_B": <number 0-5>,
  "usefulness_A": <number 0-5>,
  "usefulness_B": <number 0-5>,
  "winner": "A" or "B" or "Tie",
  "reason": "<brief 1-sentence explanation of why winner was chosen>"
}}
"""

# %%
def compress_combined_explanation(predicted_class, gradcam_text, lime_text, shap_text):

    prompt = f"""You are given three short explanations of why a CNN predicted a class for a satellite image.

Predicted class: "{predicted_class}"

Explanation 1:
{gradcam_text}

Explanation 2:
{lime_text}

Explanation 3:
{shap_text}

Your task:
- Combine these into ONE concise explanation
- Remove repeated information
- Do not add any new explanation
- Keep length similar to a normal explanation (3–4 sentences)

Return only the final combined explanation (no extra text)."""

    response = client.chat.completions.create(
        model="gpt-4.1-mini",
        messages=[{"role": "user", "content": prompt}],
        temperature=0,
        max_completion_tokens=200
    )

    return response.choices[0].message.content.strip()

# %%
exp5_clean = []

for i in range(len(exp1)):

    predicted_class = exp1.loc[i, "predicted_class"]

    gradcam_text = exp2.loc[i, "xai_explanation"]
    lime_text = exp3.loc[i, "lime_explanation"]
    shap_text = exp4.loc[i, "shap_explanation"]

    combined_clean = compress_combined_explanation(
        predicted_class,
        gradcam_text,
        lime_text,
        shap_text
    )

    exp5_clean.append({
        "index": i,
        "true_class": exp1.loc[i, "true_class"],
        "predicted_class": predicted_class,
        "combined_explanation": combined_clean
    })

    if i % 10 == 0:
        print(f"Processed {i}/{len(exp1)}")

df_exp5_clean = pd.DataFrame(exp5_clean)
# Out:
# Processed 0/120
# Processed 10/120
# Processed 20/120
# Processed 30/120
# Processed 40/120
# Processed 50/120
# Processed 60/120
# Processed 70/120
# Processed 80/120
# Processed 90/120
# Processed 100/120
# Processed 110/120

# %%
df_exp5_clean.head()
# Out:
#    index        true_class   predicted_class  \
# 0      0  annual crop land  annual crop land
# 1      1  annual crop land  annual crop land
# 2      2  annual crop land  annual crop land
# 3      3  annual crop land  annual crop land
# 4      4  annual crop land  annual crop land
#
#                                 combined_explanation
# 0  The model likely predicted "annual crop land" ...
# 1  The model likely predicted "annual crop land" ...
# 2  The model likely predicted "annual crop land" ...
# 3  The model likely predicted "annual crop land" ...
# 4  The model likely predicted "annual crop land" ...

# %%
df_exp5_clean.to_csv("exp5_results_scaled.csv", index=False)

# %%
# Pick first sample
i = 5
predicted_class = exp1.loc[i, "predicted_class"]

# Exp1 = baseline
exp1_text = exp1.loc[i, "direct_description"]
print("exp1_text:")
print(exp1_text)

# Exp2 = GradCAM (you can later switch to exp3 or exp4)
exp2_text = df_exp5_clean.loc[i, "combined_explanation"]
print("\nexp2_text:")
print(exp2_text)

# Build prompt (no bias mention)
prompt = build_combined_judge_prompt(
    predicted_class,
    exp1_text,
    exp2_text,
)

# Call Gemini
result = judge_with_openai(prompt)

print("\nResult:")
print(result)
# Out:
# exp1_text:
# The model likely predicted "annual crop land" due to the presence of rectangular or geometric patterns, which are indicative of farmland plots. The texture appears consistent with that of cultivated soil, with variations in color or shading suggesting different stages of crop growth or land preparation. The organized appearance and defined boundaries are typical characteristics of agricultural areas managed for annual crops.
#
# exp2_text:
# The model likely predicted "annual crop land" because the image displays distinct rectangular plots with uniform textures and clear, straight boundaries, characteristic of cultivated agricultural fields. These rectilinear patterns, visible in the upper-left, upper-center, and upper-right regions, suggest human planning and managed cropping systems. The arrangement and uniformity of these areas contrast with the irregular patterns typical of natural or non-agricultural land.
#
# Result:
# {'score_A': 7, 'score_B': 9, 'specificity_A': 3, 'specificity_B': 5, 'usefulness_A': 4, 'usefulness_B': 4, 'winner': 'B', 'reason': 'Explanation B provides more specific visual details and clearer spatial references, making it more informative and easier to understand.'}

# %%
results_base_vs_combined2 = []

for i in range(len(exp1)):

    predicted_class = exp1.loc[i, "predicted_class"]

    # Baseline explanation
    exp1_text = exp1.loc[i, "direct_description"]

    # Combined explanation (Exp5 output)
    exp5_text = df_exp5_clean.loc[i, "combined_explanation"]

    #  Build prompt
    prompt = build_combined_judge_prompt(
        predicted_class,
        exp1_text,
        exp5_text
    )

    #  Call judge (OpenAI)
    result = judge_with_openai(prompt)

    # Map winner labels
    winner_raw = result.get("winner")

    if winner_raw == "A":
        winner_label = "base"
    elif winner_raw == "B":
        winner_label = "Combined"
    elif winner_raw == "Tie":
        winner_label = "Tie"
    else:
        winner_label = "Error"

    # Save results
    results_base_vs_combined2.append({
        "index": i,
        "true_class": exp1.loc[i, "true_class"],
        "predicted_class": predicted_class,
        "score_base": result.get("score_A"),
        "score_combined": result.get("score_B"),
        "specificity_base": result.get("specificity_A"),
        "specificity_combined": result.get("specificity_B"),
        "usefulness_base": result.get("usefulness_A"),
        "usefulness_combined": result.get("usefulness_B"),
        "winner": winner_label,
        "reason": result.get("reason")
    })

    # Progress update
    if i % 10 == 0:
        print(f"Processed {i}/{len(exp1)}")
# Out:
# Processed 0/120
# Processed 10/120
# Processed 20/120
# Processed 30/120
# Processed 40/120
# Processed 50/120
# Processed 60/120
# Processed 70/120
# Processed 80/120
# Processed 90/120
# Processed 100/120
# Processed 110/120

# %%
df_exp16 = pd.DataFrame(results_base_vs_combined2)

# %%
print(df_exp16["winner"].value_counts())
# Out:
# winner
# Combined    91
# Tie         21
# base         8
# Name: count, dtype: int64

# %%
total = len(df_exp16)

combined_wins = (df_exp16["winner"] == "Combined").sum()
base_wins = (df_exp16["winner"] == "base").sum()
ties = (df_exp16["winner"] == "Tie").sum()

print(f"Combined win rate: {combined_wins/total*100:.2f}%")
print(f"Baseline win rate: {base_wins/total*100:.2f}%")
print(f"Tie rate: {ties/total*100:.2f}%")

avg_base = df_exp16["score_base"].mean()
avg_combined = df_exp16["score_combined"].mean()

print(f"Avg Base Score: {avg_base:.2f}")
print(f"Avg Combined Score: {avg_combined:.2f}")

improvement = ((avg_combined - avg_base) / avg_base) * 100
print(f"Improvement: {improvement:.2f}%")
# Out:
# Combined win rate: 75.83%
# Baseline win rate: 6.67%
# Tie rate: 17.50%
# Avg Base Score: 7.57
# Avg Combined Score: 8.97
# Improvement: 18.50%

# %%
df_exp16.to_csv(f"exp6_base_vs_combined_clean.csv", index=False)

# %% [markdown]
# ## Quantitative result

# %%
import pandas as pd

files = {
    "Grad-CAM": {
        "path": "exp2_gradcam_evaluation.csv",
        "xai_spec": "specificity_gradcam",
        "xai_use": "usefulness_gradcam",
        "xai_score": "score_gradcam"
    },
    "LIME": {
        "path": "exp3_lime_evaluation.csv",
        "xai_spec": "specificity_lime",
        "xai_use": "usefulness_lime",
        "xai_score": "score_lime"
    },
    "SHAP": {
        "path": "exp4_shap_evaluation.csv",
        "xai_spec": "specificity_shap",
        "xai_use": "usefulness_shap",
        "xai_score": "score_shap"
    },
    "Combined XAI": {
        "path": "exp6_base_vs_combined_clean.csv",
        "xai_spec": "specificity_combined",
        "xai_use": "usefulness_combined",
        "xai_score": "score_combined"
    }
}

rows = []

for method, info in files.items():
    df = pd.read_csv(info["path"])

    avg_base_spec = df["specificity_base"].mean()
    avg_xai_spec = df[info["xai_spec"]].mean()

    avg_base_use = df["usefulness_base"].mean()
    avg_xai_use = df[info["xai_use"]].mean()

    avg_base_score = df["score_base"].mean()
    avg_xai_score = df[info["xai_score"]].mean()

    improvement = ((avg_xai_score - avg_base_score) / avg_base_score) * 100

    rows.append({
        "Method": method,
        "Avg Base Specificity": round(avg_base_spec, 2),
        "Avg XAI Specificity": round(avg_xai_spec, 2),
        "Avg Base Usefulness": round(avg_base_use, 2),
        "Avg XAI Usefulness": round(avg_xai_use, 2),
        "Avg Base Score": round(avg_base_score, 2),
        "Avg XAI Score": round(avg_xai_score, 2),
        "Improvement": f"{improvement:.2f}%"
    })

results_table = pd.DataFrame(rows)

results_table
# Out:
#          Method  Avg Base Specificity  Avg XAI Specificity  \
# 0      Grad-CAM                  4.27                 4.22
# 1          LIME                  4.07                 4.40
# 2          SHAP                  4.32                 4.16
# 3  Combined XAI                  3.80                 4.92
#
#    Avg Base Usefulness  Avg XAI Usefulness  Avg Base Score  Avg XAI Score  \
# 0                 3.88                3.98            8.15           8.21
# 1                 3.85                3.97            7.92           8.37
# 2                 3.89                3.94            8.21           8.10
# 3                 3.77                4.05            7.57           8.97
#
#   Improvement
# 0       0.72%
# 1       5.68%
# 2      -1.32%
# 3      18.50%

# %% [markdown]
# ## Pairwise Comparison Results

# %%
import pandas as pd

files = {
    "Grad-CAM": {
        "path": "exp2_gradcam_evaluation.csv",
        "xai_label": "GradCAM"
    },
    "LIME": {
        "path": "exp3_lime_evaluation.csv",
        "xai_label": "LIME"
    },
    "SHAP": {
        "path": "exp4_shap_evaluation.csv",
        "xai_label": "SHAP"
    },
    "Combined XAI": {
        "path": "exp6_base_vs_combined_clean.csv",
        "xai_label": "Combined"
    }
}

rows = []

for method, info in files.items():
    df = pd.read_csv(info["path"])
    total = len(df)

    baseline_win = (df["winner"] == "base").sum() / total * 100
    xai_win = (df["winner"] == info["xai_label"]).sum() / total * 100
    tie = (df["winner"] == "Tie").sum() / total * 100

    rows.append({
        "Method": method,
        "Baseline Win %": round(baseline_win, 2),
        "XAI Win %": round(xai_win, 2),
        "Tie %": round(tie, 2)
    })

winrate_table = pd.DataFrame(rows)

winrate_table

# %% [markdown]
# ## Experiement with one sample per class

# %%
base = pd.read_csv(f"direct_descriptions.csv")
gradcam = pd.read_csv(f"gradcam_explanations_selected_samples.csv")
lime = pd.read_csv(f"lime_explanations_selected_samples.csv")
shap = pd.read_csv(f"shap_explanations_selected_samples.csv")

# Check shapes
print("Exp1:", base.shape)
print("Exp2:", gradcam.shape)
print("Exp3:", lime.shape)
print("Exp4:", shap.shape)
# Out:
# Exp1: (6, 4)
# Exp2: (6, 5)
# Exp3: (6, 5)
# Exp4: (6, 5)

# %%
combined_explanations_selected_samples = []

for i in range(len(base)):

    predicted_class = base.loc[i, "predicted_class"]

    gradcam_text = gradcam.loc[i, "xai_explanation"]
    lime_text = lime.loc[i, "lime_explanation"]
    shap_text = shap.loc[i, "shap_explanation"]

    combined_clean = compress_combined_explanation(
        predicted_class,
        gradcam_text,
        lime_text,
        shap_text
    )

    combined_explanations_selected_samples.append({
        "index": i,
        "true_class": exp1.loc[i, "true_class"],
        "predicted_class": predicted_class,
        "combined_explanation": combined_clean
    })

    if i % 10 == 0:
        print(f"Processed {i}/{len(base)}")

df_combined_explanations_selected_samples = pd.DataFrame(combined_explanations_selected_samples)
# Out:
# Processed 0/6

# %%
df_combined_explanations_selected_samples.to_csv("combined_explanations_selected_samples.csv", index=False)
